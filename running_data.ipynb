# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
data = pd.read_csv('final_project.csv')

# %%
data.head()
# Out:
#     duration  totalDistance  min per mile       date Time of Day Day of Week  \
# 0  54.299162       3.082548     17.615026   5/3/2020       11:34           U
# 1  36.192167       2.260464     16.010944   5/4/2020       12:48           M
# 2  34.323762       2.255432     15.218264   5/6/2020       14:55           W
# 3  36.649868       2.255067     16.252231  5/11/2020       14:55           M
# 4  38.678290       2.286366     16.916928  5/12/2020       13:04           T
#
#    Audio Hours of Sleep  Water (ounces)  Defect (Y/N)
# 0  MUSIC          07:46              32          True
# 1  MUSIC          08:28              32          True
# 2  MUSIC          08:52              32          True
# 3  MUSIC          08:39              32          True
# 4  MUSIC          08:09              32          True

# %%
data.dtypes
# Out:
# duration          float64
# totalDistance     float64
# min per mile      float64
# date               object
# Time of Day        object
# Day of Week        object
# Audio              object
# Hours of Sleep     object
# Water (ounces)      int64
# Defect (Y/N)         bool
# dtype: object

# %%
data['Hours of Sleep'] = pd.to_datetime(data['Hours of Sleep'], format='%H:%M%:%S', errors='ignore')

# %%
data['Hours of Sleep'] = data['Hours of Sleep'].apply(lambda x: datetime.strptime(x, '%H:%M'))

# %%
data['Hours of Sleep'] = data['Hours of Sleep'].apply(lambda x: x.hour + x.minute / 60)

# %%
data.dtypes
# Out:
# duration          float64
# totalDistance     float64
# min per mile      float64
# date               object
# Time of Day        object
# Day of Week        object
# Audio              object
# Hours of Sleep    float64
# Water (ounces)      int64
# Defect (Y/N)         bool
# dtype: object

# %%
sns.pairplot(data)
# Out:
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
data.describe()
# Out:
#         duration  totalDistance  min per mile  Hours of Sleep  Water (ounces)
# count  55.000000      55.000000     55.000000       55.000000       55.000000
# mean   41.731736       2.659104     15.802749        7.770606       58.181818
# std     6.179849       0.445049      1.448483        0.647931       20.509339
# min    31.449821       2.126302     13.812246        6.416667       32.000000
# 25%    38.182194       2.276930     14.724710        7.458333       32.000000
# 50%    40.460950       2.696751     15.357479        7.766667       64.000000
# 75%    44.926079       2.820879     16.815854        8.233333       64.000000
# max    71.399759       4.470661     20.551287        9.083333       96.000000

# %%
data.head()
# Out:
#     duration  totalDistance  min per mile       date Time of Day Day of Week  \
# 0  54.299162       3.082548     17.615026   5/3/2020       11:34           U
# 1  36.192167       2.260464     16.010944   5/4/2020       12:48           M
# 2  34.323762       2.255432     15.218264   5/6/2020       14:55           W
# 3  36.649868       2.255067     16.252231  5/11/2020       14:55           M
# 4  38.678290       2.286366     16.916928  5/12/2020       13:04           T
#
#    Audio  Hours of Sleep  Water (ounces)  Defect (Y/N)
# 0  MUSIC        7.766667              32          True
# 1  MUSIC        8.466667              32          True
# 2  MUSIC        8.866667              32          True
# 3  MUSIC        8.650000              32          True
# 4  MUSIC        8.150000              32          True

# %%
plt.rcParams['figure.figsize'] = [12, 8]

# %%
sns.boxplot(x='Day of Week', y='min per mile', data=data)

# %%
sns.boxplot(x='Water (ounces)', y='min per mile', data=data)

# %%
sns.boxplot(x='Audio', y='min per mile', data=data)

# %%
sns.scatterplot(x=data['Hours of Sleep'], y=data['min per mile'], hue=data['Day of Week'])

# %%
sns.distplot(data['min per mile'])
